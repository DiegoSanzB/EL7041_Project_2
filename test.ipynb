# %%
from vars import *
# %matplotlib inline
#
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Plot modulated data

# %% [markdown]
# ## Just modulated

# %% [markdown]
# ### QPSK

# %%
data = pd.read_csv('results/QPSK.csv')
data = data[ ["clean_re", "clean_im"]]
data_array = data.to_numpy()
# De-normalize for colors
data_colors = np.rint(data_array*np.sqrt(2))
color_dots4 = []
for i in range(len(data_array)):
    color_dots4.append(COLOR[str(MOD4.index(data_colors[i].tolist()))])
# Separate coordinates
real = data_array[:, 0]
imag = data_array[:, 1]
# Create a figure and a set of subplots
fig1, axs1 = plt.subplots(1)
axs1.set_title("Modulated data")
axs1.set_xlabel(r"$\Re$(-)")
axs1.set_ylabel(r"$\Im$(-)")
axs1.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
axs1.set_ylim(-1.5, 1.5)  # Set limits for the y-axis
# axs1.grid()
# Plot the data
axs1.scatter(real, imag, color = color_dots4, zorder = 7)
# Insert handmade legend
axs1.legend(handles = LEG4)
# axs1.figure.savefig('results/clean_QPSK.pdf')

# %% [markdown]
# ### 16QAM

# %%
data = pd.read_csv('results/16QAM.csv')

data = data[ ["clean_re", "clean_im"]]
data_array = data.to_numpy()
data_colors = np.rint(data_array*np.sqrt(10))
color_dots16 = []
for i in range(len(data_array)):
    color_dots16.append(COLOR[str(MOD16.index(data_colors[i].tolist()))])
# Separate coordinates
real = data_array[:, 0]
imag = data_array[:, 1]
# Create a figure and a set of subplots
fig1, axs1 = plt.subplots(1)
axs1.set_title("Modulated data")
axs1.set_xlabel(r"$\Re$(-)")
axs1.set_ylabel(r"$\Im$(-)")
axs1.set_xlim(-1.20, 1.9)  # Set limits for the x-axis
axs1.set_ylim(-1.20, 1.3)  # Set limits for the y-axis
# axs1.grid()
# Plot the data
axs1.scatter(real, imag, color = color_dots16, zorder = 7)
# Insert handmade legend
axs1.legend(handles=LEG16)
# axs1.figure.savefig('results/clean_16QAM.pdf')

# %% [markdown]
# ## With noise

# %% [markdown]
# ### QPSK

# %%
data = pd.read_csv('results/QPSK_snr.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("QPSK_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 1.5)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, color = color_dots4, zorder = 7)
    # Insert handmade legend
# Set legend outside the plot
fig.legend(handles=LEG4, bbox_to_anchor=(0.9, 0.5), loc='center left')

# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/QPSK_SNR.png')
print("Done")
plt.show()
# Out:
# Done

# %% [markdown]
# ### 16QAM

# %%
data = pd.read_csv('results/16QAM_snr.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # print(i)
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 1.5)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, color = color_dots16, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_SNR.png')
print("Done")
plt.show()
# Out:
# Done

# %% [markdown]
# ## With Rayleigh wea

# %% [markdown]
# ### QPSK

# %%
data = pd.read_csv('results/QPSK_rayleigh.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("QPSK_rayleigh_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 1.5)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, color = color_dots4, zorder = 7)
    # Insert handmade legend
# Set legend outside the plot
fig.legend(handles=LEG4, bbox_to_anchor = (0.9, 0.5), loc = 'center left')

# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/QPSK_RAYLEIGH.png')
print("Done")
plt.show()
# Out:
# Done

# %% [markdown]
# ### 16QAM

# %%
data = pd.read_csv('results/16QAM_rayleigh.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 1.5)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, color = color_dots16, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_RAYLEIGH.png')
print("Done")
plt.show()
# Out:
# Done

# %% [markdown]
# ## Doppler wea

# %% [markdown]
# ### QPSK

# %%
data = pd.read_csv('results/QPSK_doppler.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("QPSK_doppler_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-5.70, 5.7)  # Set limits for the x-axis
    # ax.set_ylim(-5.5, 5.5)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, color = color_dots4, zorder = 7)
    # Insert handmade legend
# Set legend outside the plot
fig.legend(handles=LEG4, bbox_to_anchor = (0.9, 0.5), loc = 'center left')

# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/QPSK_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %% [markdown]
# ### 16QAM

# %%
data = pd.read_csv('results/16QAM_doppler.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 2)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, color = color_dots16, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %% [markdown]
# # Equalizations

# %%
# First get color array without pilots

# %% [markdown]
# ## Perfect channel

# %%
data = pd.read_csv('results/QPSK_eq_doppler_perfect.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    ax.set_ylim(-1.8, 2)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %%
data = pd.read_csv('results/QPSK_eq_rayleigh_perfect.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 2)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %%
data = pd.read_csv('results/16QAM_eq_doppler_perfect.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 2)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %%
data = pd.read_csv('results/16QAM_eq_rayleigh_perfect.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.70, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 2)  # Set limits for the y-axis
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %%
data = pd.read_csv('results/16QAM_eq_doppler_cubic.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("16QAM_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.7, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 2)  # Set limits for the y-axis
    # ax.set_xlim(-5, 5)
    # ax.set_ylim(-5, 5)
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done

# %%
data = pd.read_csv('results/QPSK_eq_doppler_cubic.csv')
# create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)
fig.suptitle("QPSK_SNR")
# Get the SNR values
# Iterate over the subplots
for i in range(4):
    # Select the subplot
    ax = axs[i // 2, i % 2]
    ax.set_title("SNR = " + str(SNR[i]) + " dB")
    ax.set_xlabel(r"$\Re$(-)")
    ax.set_ylabel(r"$\Im$(-)")
    # ax.set_xlim(-1.7, 1.7)  # Set limits for the x-axis
    # ax.set_ylim(-1.5, 2)  # Set limits for the y-axis
    # ax.set_xlim(-5, 5)
    # ax.set_ylim(-5, 5)
    # Separate coordinates and get them as a numpy array
    real = data[f"{SNR[i]}_re"].to_numpy()
    imag = data[f"{SNR[i]}_im"].to_numpy()
    # Plot the data
    ax.scatter(real, imag, zorder = 7)
# Set legend outside the plot
fig.legend(handles=LEG16, bbox_to_anchor=(0.9, 0.5), loc='center left')
# Adjust layout to prevent overlap with the title
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
# print("Done")
# plt.savefig('results/16QAM_DOPPLER.png')
print("Done")
plt.show()
# Out:
# Done
